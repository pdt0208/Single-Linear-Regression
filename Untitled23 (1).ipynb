# %%
# Simple Linear Regression - Practical Example

# %%
## Problem Statement -

# %%
# !pip install statsmodels

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set()
import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
raw_data = pd.read_csv ('anaconda3/Salary_dataset.csv')
raw_data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
# 1) CLEAN DATA

# %%
data = raw_data.copy()

# %%
data = raw_data.drop(['Unnamed: 0'] , axis = 1)

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
# 2) Relax Assumptions

# %%
# Exploring PDF

# %%
sns.displot(data['Salary'])

# %%
sns.displot(data['YearsExperience'])

# %%
plt.figure(figsize=(5,3))
ax1 = plt.subplot(111)

ax1.scatter(data['YearsExperience'], data['Salary'])
ax1.set_title('YearsExperience and Salary')

plt.show()

# %%
x = data[['YearsExperience']]
y = data['Salary']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=15)

# %%
x_train
# Out:
#     YearsExperience
# 3               2.1
# 26              9.6
# 25              9.1
# 9               3.8
# 4               2.3
# 20              6.9
# 10              4.0
# 24              8.8
# 13              4.2
# 17              5.4
# 15              5.0
# 28             10.4
# 11              4.1
# 7               3.3
# 0               1.2
# 23              8.3
# 5               3.0
# 12              4.1
# 21              7.2
# 8               3.3

# %%
x_test
# Out:
#     YearsExperience
# 16              5.2
# 14              4.6
# 27              9.7
# 22              8.0
# 19              6.1
# 18              6.0
# 1               1.4
# 2               1.6
# 29             10.6
# 6               3.1

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler = StandardScaler()
x_train_scaler=Scaler.fit_transform(x_train)
x_test_scaler=Scaler.transform(x_test)

# %%
reg = LinearRegression()
reg.fit(x_train_scaler, y_train)
yhat = reg.predict(x_test_scaler)

# %%
plt.scatter(x_test_scaler,y_test)
plt.plot(x_test_scaler,yhat,color="orange")
plt.show()

# %%
plt.scatter(x_train_scaler,y_train)
plt.plot(x_train_scaler,reg.predict(x_train_scaler),color="r")
plt.show()

# %%
mae=mean_absolute_error(y_test,yhat)
mse=mean_squared_error(y_test,yhat)
r2Score=r2_score(y_test,yhat)
print("Mean Absolute Error:",mae)
print("Mean Squared Error:",mse)
print("R2 Score:",r2Score)
# Out:
# Mean Absolute Error: 5410.170805015662
# Mean Squared Error: 43103220.442744456
# R2 Score: 0.9410501496233283

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=15)

# %%
y_train
# Out:
# 3      43526.0
# 26    116970.0
# 25    105583.0
# 9      57190.0
# 4      39892.0
# 20     91739.0
# 10     63219.0
# 24    109432.0
# 13     57082.0
# 17     83089.0
# 15     67939.0
# 28    122392.0
# 11     55795.0
# 7      54446.0
# 0      39344.0
# 23    113813.0
# 5      56643.0
# 12     56958.0
# 21     98274.0
# 8      64446.0
# Name: Salary, dtype: float64

# %%
y_test
# Out:
# 16     66030.0
# 14     61112.0
# 27    112636.0
# 22    101303.0
# 19     93941.0
# 18     81364.0
# 1      46206.0
# 2      37732.0
# 29    121873.0
# 6      60151.0
# Name: Salary, dtype: float64

# %%
Scaler = StandardScaler()
y_train_scaler=Scaler.fit_transform(x_train)
y_test_scaler=Scaler.transform(x_test)

# %%
reg = LinearRegression()
reg.fit(y_train_scaler, x_train)
yhat = reg.predict(y_test_scaler)

# %%
plt.scatter(y_test,yhat)
plt.show()

# %% [markdown]
# ## x = sm.add_constant(x)   # IMPORTANT
#
# model = sm.OLS(y, x).fit()
#
# print(model.summary())

# %%
x = np.array(x)
y = np.array(y)

# %%
x_log = np.log(x)
y_log = np.log(y)

# %%
x_log = np.log(x + 1)
y_log = np.log(y + 1)

# %%
plt.scatter(x_log, y_log)
plt.xlabel('log(SAT)', fontsize=20)
plt.ylabel('log(GPA)', fontsize=20)
plt.title('Log-Log Scale')
plt.show()

# %%
x_log  = sm.add_constant(data['YearsExperience'])
#y = np.log(data['Salary'])

model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Fri, 26 Dec 2025   Prob (F-statistic):           1.14e-20
# Time:                        18:10:26   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            2.485e+04   2306.654     10.772      0.000    2.01e+04    2.96e+04
# ...

# %%
x_sorted = np.sort(x_log)
yhat = 5 * x_sorted + 10.49   # example coefficients

plt.scatter(x_log, y_log)
plt.plot(x_sorted, yhat, lw=4, c='orange')
plt.xlabel('log(SAT)', fontsize=20)
plt.ylabel('log(GPA)', fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[333], line 1
# ----> 1 plt.scatter (x,y)
#       2 yhat = 9449*x + 2.45
#       3 fig = plt.plot(x,yhat,lw=4,c='orange',label='regression')
#
# File ~\Anacondanew\envs\notebook\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...
